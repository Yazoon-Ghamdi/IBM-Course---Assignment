# %% [markdown]
# ### **Read The Dataset and Display**

# %%
import pandas as pd

# قراءة الملف
df = pd.read_csv("kc_house_data.csv")

# عرض أنواع بيانات كل عمود
print(df.dtypes)
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# **Clean The Data**

# %%
# حذف الأعمدة فقط إذا كانت موجودة
columns_to_drop = ['id', 'Unnamed: 0']
df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

# عرض ملخص إحصائي
print(df.describe())
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# **Explore and Show the data**

# %%
# استخدام value_counts مع to_frame لعرض عدد المنازل حسب قيمة الطوابق
floors_count_df = df['floors'].value_counts().to_frame()

# إعادة تسمية العمود الناتج لتوضيح المعنى
floors_count_df.columns = ['count']

# عرض النتيجة
print(floors_count_df)
# Out:
#         count
# floors
# 1.0     10680
# 2.0      8241
# 1.5      1910
# 3.0       613
# 2.5       161
# 3.5         8

# %% [markdown]
# **Visualazations using EDA**

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# إنشاء boxplot للمقارنة بين المنازل ذات الإطلالة المائية والتي بدون
plt.figure(figsize=(10, 6))
sns.boxplot(x='waterfront', y='price', data=df)
plt.title('Boxplot of House Prices by Waterfront View')
plt.xlabel('Waterfront (0 = No, 1 = Yes)')
plt.ylabel('Price')
plt.show()

# %%
# إنشاء الرسم البياني باستخدام regplot
plt.figure(figsize=(10, 6))
sns.regplot(x="sqft_above", y="price", data=df)
plt.title("Relationship between sqft_above and price")
plt.xlabel("Square Feet Above Ground")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### **Build The Linear Regression Model**

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# تحميل البيانات
df = pd.read_csv("kc_house_data.csv")

# اختيار المتغيرات
X = df[['sqft_living']]  # الميزة المستقلة (مصفوفة 2D)
y = df['price']          # المتغير التابع

# إنشاء نموذج الانحدار وتدريبه
lm = LinearRegression()
lm.fit(X, y)

# حساب معامل التحديد R^2
r2 = lm.score(X, y)
print(f"R^2 value: {r2}")
# Out:
# R^2 value: 0.4928532179037931

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# قراءة البيانات
df = pd.read_csv("kc_house_data.csv")

# تحديد الميزات المطلوبة
features = [
    "floors",
    "waterfront",
    "lat",
    "bedrooms",
    "sqft_basement",
    "view",
    "bathrooms",
    "sqft_living15",
    "sqft_above",
    "grade",
    "sqft_living"
]

# المتغيرات المستقلة والتابعة
X = df[features]
y = df['price']

# إنشاء النموذج وتدريبه
lm = LinearRegression()
lm.fit(X, y)

# حساب R²
r2 = lm.score(X, y)
print(f"R^2 value: {r2}")
# Out:
# R^2 value: 0.6577151058279325

# %% [markdown]
# **Create pipeline**

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("kc_house_data.csv")

# Selected features
features = [
    "floors",
    "waterfront",
    "lat",
    "bedrooms",
    "sqft_basement",
    "view",
    "bathrooms",
    "sqft_living15",
    "sqft_above",
    "grade",
    "sqft_living"
]

# Drop missing values
df_clean = df.dropna(subset=features + ["price"])

X = df_clean[features]
y = df_clean["price"]

# Build pipeline
pipeline = Pipeline([
    ('scale', StandardScaler()),
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('model', LinearRegression())
])

# Fit the pipeline
pipeline.fit(X, y)

# Calculate R^2
r2 = pipeline.score(X, y)
print(f"R^2 (Polynomial Regression): {r2:.4f}")
# Out:
# R^2 (Polynomial Regression): 0.7513

# %% [markdown]
# **Ridge regression**

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("kc_house_data.csv")

# Select features and target
features = [
    "floors", "waterfront", "lat", "bedrooms",
    "sqft_basement", "view", "bathrooms", "sqft_living15",
    "sqft_above", "grade", "sqft_living"
]
X = df[features]
y = df["price"]

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create and fit Ridge regression model
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(X_train, y_train)

# Calculate R^2 score on the test set
r2_score = ridge_model.score(X_test, y_test)
print(f"R^2 score (Ridge Regression, alpha=0.1): {r2_score:.4f}")
# Out:
# R^2 score (Ridge Regression, alpha=0.1): 0.6460

# %% [markdown]
# **second-order polynomial transformation**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# Load dataset
df = pd.read_csv("kc_house_data.csv")

# Select features and target
features = [
    "floors", "waterfront", "lat", "bedrooms",
    "sqft_basement", "view", "bathrooms", "sqft_living15",
    "sqft_above", "grade", "sqft_living"
]
X = df[features]
y = df["price"]

# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# 1. Polynomial transformation (degree=2)
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# 2. Create and fit Ridge regression model
ridge_poly = Ridge(alpha=0.1)
ridge_poly.fit(X_train_poly, y_train)

# 3. Predict and calculate R^2 on test data
r2 = ridge_poly.score(X_test_poly, y_test)
print(f"R^2 score with 2nd-degree Polynomial + Ridge (alpha=0.1): {r2:.4f}")
# Out:
# R^2 score with 2nd-degree Polynomial + Ridge (alpha=0.1): 0.7546
